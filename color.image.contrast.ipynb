# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread('/root/Desktop/python/condor.jpeg')
img1=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
mask=np.zeros(img1.shape[:2],np.uint8)
plt.imshow(mask,cmap='gray')

# %%
mask[25:75,50:300]=255

# %%
plt.imshow(mask,cmap='gray')

# %%
masked_image=cv2.bitwise_and(image,image,mask=mask) #histogram calculation calculation

# %%
show_masked_image=cv2.bitwise_and(img1,img1,mask=mask) #color corrected

# %%
plt.imshow(show_masked_image,cmap='gray')

# %%
hist_max_values_red=cv2.calcHist([image],channels=[0],mask=mask,histSize=[256],ranges=[0,256])

# %%
hist_values_red=cv2.calcHist([image],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.imshow(hist_max_values_red)
plt.title('histogram for red values')
# Out:
# Text(0.5, 1.0, 'histogram for red values')

# %%
plt.calcHist(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-77d8ca1011e9> in <module>
# ----> 1 plt.calcHist(img)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'calcHist'

# %%
'''before this is the bs code that works partially'''
# Out:
# 'before this is the bs code that works partially'

# %%
ima=cv2.imread('/root/Desktop/python/condor.jpeg',0)
image=cv2.cvtColor(ima,cv2.COLOR_BGR2RGB)

# %%
def disp_image(img,cmap='None'):
    fig=plt.figure(figsize=(10,8))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
disp_image(image,cmap='gray')

# %%
image.shape
# Out:
# (151, 333, 3)

# %%
histvalues=cv2.calcHist([image],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(histvalues)

# %%
ima=cv2.imread('/root/Desktop/python/condor.jpeg',0)
#image=cv2.cvtColor(ima,cv2.COLOR_BGR2RGB)

# %%
def display(img,cmap=None):
    fig=plt.figure(figsize=(10,8))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
display(ima,cmap='gray')

# %%
hist_values=cv2.calcHist([ima],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
eqimg=cv2.equalizeHist(ima)
disp_image(eqimg,cmap='gray')

# %%
hist_values=cv2.calcHist([eqimg],channels=[0],mask=None,histSize=[256],ranges=[0,256])
plt.plot(hist_values)

# %%
bird=cv2.imread('/root/Desktop/python/condor.jpeg')
showbird=cv2.cvtColor(bird,cv2.COLOR_BGR2RGB)

display(showbird)

# %%
hsv=cv2.cvtColor(bird,cv2.COLOR_BGR2HSV)

# %%
hsv
# Out:
# array([[[108, 206, 249],
#         [108, 206, 249],
#         [107, 207, 249],
#         ...,
#         [107, 206, 248],
#         [107, 206, 248],
#         [107, 206, 248]],
#
#        [[108, 206, 249],
#         [108, 206, 249],
#         [107, 207, 249],
#         ...,
#         [107, 206, 248],
#         [107, 206, 248],
#         [107, 206, 248]],
#
#        [[108, 206, 249],
#         [108, 206, 249],
#         [107, 207, 249],
#         ...,
#         [107, 205, 248],
#         [107, 205, 248],
#         [107, 205, 248]],
#
#        ...,
#
#        [[107, 213, 248],
#         [107, 213, 248],
#         [107, 213, 248],
#         ...,
#         [107, 205, 246],
#         [108, 203, 246],
#         [108, 200, 246]],
#
#        [[107, 213, 248],
#         [107, 213, 248],
#         [107, 213, 248],
#         ...,
#         [107, 205, 246],
#         [107, 205, 246],
#         [108, 203, 246]],
#
#        [[107, 213, 248],
#         [107, 213, 248],
#         [107, 213, 248],
# ...

# %%
hsv[:,:,2]=cv2.equalizeHist(hsv[:,:,2])

# %%
contrasted_bird=cv2.cvtColor(hsv,cv2.COLOR_HSV2RGB)

# %%
display(contrasted_bird)
