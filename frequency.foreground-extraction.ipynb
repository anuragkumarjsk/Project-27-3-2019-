# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

#reading image
img=cv2.imread('/root/Desktop/python/flock1.jpeg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img,cmap='gray')

#image dimensions
rows,columns=img.shape
print(rows,columns)

#2d to 1d array
matrix=img.ravel()

#each pixel frequency
x=np.array(matrix)
y = np.bincount(x)
ii = np.nonzero(y)[0]
    
    
np.vstack((ii,y[ii])).T 



#interactive foreground image extraction
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/root/Desktop/python/flock2.jpeg')
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

dsplay(img)

rect = (50,50,175,200)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]

plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# 183 276
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0c85f8695a84> in <module>
#      36 fgdModel = np.zeros((1,65),np.float64)
#      37
# ---> 38 dsplay(img)
#      39
#      40 rect = (50,50,175,200)
#
# NameError: name 'dsplay' is not defined

# %%
#display functon for def dsplay(image):
    fig=plt.figure(figsize=(15,15))
    ax=fig.add_subplot(111)
    ax.imshow(image)
