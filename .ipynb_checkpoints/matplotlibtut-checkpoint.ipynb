# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
pic=Image.open("/root/Desktop/python/brd.jpeg")
picarray=np.asarray(pic)
plt.imshow(picarray)

# %%
picred=picarray.copy()

# %%
picred
# Out:
# array([[[249, 240, 241],
#         [249, 240, 241],
#         [249, 240, 241],
#         ...,
#         [254, 252, 253],
#         [255, 254, 255],
#         [255, 254, 255]],
#
#        [[249, 240, 241],
#         [249, 240, 241],
#         [249, 240, 241],
#         ...,
#         [254, 252, 253],
#         [255, 254, 255],
#         [255, 254, 255]],
#
#        [[249, 240, 241],
#         [249, 240, 241],
#         [249, 240, 241],
#         ...,
#         [254, 252, 253],
#         [255, 254, 255],
#         [255, 254, 255]],
#
#        ...,
#
#        [[216, 203, 210],
#         [216, 203, 210],
#         [217, 204, 211],
#         ...,
#         [234, 224, 223],
#         [234, 224, 223],
#         [234, 224, 223]],
#
#        [[216, 203, 210],
#         [216, 203, 210],
#         [217, 204, 211],
#         ...,
#         [234, 224, 223],
#         [234, 224, 223],
#         [234, 224, 223]],
#
#        [[216, 203, 212],
#         [216, 203, 212],
#         [217, 204, 213],
#         ...,
#         [233, 223, 222],
#         [233, 223, 222],
#         [233, 223, 222]]], dtype=uint8)

# %%
picred.shape
# Out:
# (126, 189, 3)

# %%
plt.imshow(picred[:,:,0],cmap='gray',alpha=0.5)
