# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
flat_chess=cv2.imread('/root/Desktop/python/chess.jpeg')

# %%
plt.imshow(flat_chess)

# %%
found,corners=cv2.findChessboardCorners(flat_chess,(7,7))

# %%
corners
# Out:
# array([[[ 35.23203 ,  32.889565]],
#
#        [[ 60.75318 ,  33.066635]],
#
#        [[ 86.84679 ,  32.313072]],
#
#        [[112.47616 ,  32.430183]],
#
#        [[138.20288 ,  32.609673]],
#
#        [[164.1703  ,  32.82996 ]],
#
#        [[189.96712 ,  32.905746]],
#
#        [[ 34.960068,  57.275723]],
#
#        [[ 60.995213,  57.18375 ]],
#
#        [[ 86.56737 ,  57.25395 ]],
#
#        [[112.478584,  57.285343]],
#
#        [[138.4177  ,  57.22847 ]],
#
#        [[164.28226 ,  57.307014]],
#
#        [[189.94922 ,  57.22303 ]],
#
#        [[ 34.849663,  82.15077 ]],
#
#        [[ 60.502323,  82.22097 ]],
#
#        [[ 86.5462  ,  81.925354]],
#
#        [[112.60713 ,  82.12996 ]],
#
#        [[138.74683 ,  81.888695]],
#
#        [[164.7232  ,  82.038994]],
#
#        [[190.44395 ,  82.26268 ]],
#
#        [[ 35.007484, 107.821106]],
#
#        [[ 60.709873, 107.85053 ]],
#
#        [[ 86.37607 , 107.50161 ]],
#
#        [[112.536224, 107.49532 ]],
#
#        [[138.85316 , 107.61426 ]],
#
#        [[165.08047 , 107.487076]],
#
#        [[190.69165 , 107.57236 ]],
#
#        [[ 35.016743, 132.83456 ]],
#
#        [[ 60.095104, 132.96428 ]],
#
#        [[ 86.343155, 133.0799  ]],
#
#        [[112.70732 , 133.02452 ]],
#
#        [[138.94601 , 132.91158 ]],
#
#        [[164.84134 , 132.99236 ]],
#
#        [[190.77278 , 132.77573 ]],
#
#        [[ 34.79331 , 158.3802  ]],
#
#        [[ 60.23542 , 158.37648 ]],
#
#        [[ 86.39185 , 158.72783 ]],
#
#        [[112.53888 , 158.57077 ]],
#
#        [[138.82288 , 158.72235 ]],
#
#        [[165.02463 , 158.33061 ]],
#
#        [[190.75618 , 158.32706 ]],
#
#        [[ 34.583954, 183.99586 ]],
#
#        [[ 60.144596, 184.10199 ]],
#
#        [[ 86.50333 , 184.05748 ]],
#
#        [[112.26871 , 184.18892 ]],
#
#        [[139.02753 , 184.147   ]],
#
#        [[164.76355 , 184.2877  ]],
#
#        [[190.96928 , 183.94672 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[254, 244, 244],
#         [255, 248, 248],
#         [255, 254, 254],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 254, 254],
#         [255, 254, 254],
#         [255, 255, 254],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 253, 253],
#         [255, 253, 253],
#         [255, 251, 252],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 252, 254],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 252, 254],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]]], dtype=uint8)

# %%
plt.imshow(flat_chess)
